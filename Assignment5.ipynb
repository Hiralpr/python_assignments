# %% [markdown]
# 1. What does an empty dictionary's code look like?

# %%
dictionary = dict()

# %%
print(type(dictionary))
# Out:
# <class 'dict'>

# %% [markdown]
# 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
d1 = {
    'foo' : 42
}

# %% [markdown]
# 3. What is the most significant distinction between a dictionary and a list?
#
#         - dictionary having a data as key value pair and in list having a data in form fo array.

# %% [markdown]
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam = dict(bar = 100)

# %%
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-9b5a94d1de8d> in <module>()
# ----> 1 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# 5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.keys()?

# %%
spam = dict(cat = '100')

# %%
if 'cat' in spam:
    print('present')
else:
    print('not present')
# Out:
# present

# %%
spam.keys()
# Out:
# dict_keys(['cat'])

# %% [markdown]
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %%
if 'cat' in spam:
    print('present')
else:
    print('not present')
# Out:
# present

# %%
spam.values()
# Out:
# dict_values(['100'])

# %% [markdown]
# 7. What is a shortcut for the following code?
# if &#39;color&#39; not in spam:
# spam['color'] = 'black'

# %%
spam.setdefault('color', 'black')
# Out:
# 'black'

# %%
spam
# Out:
# {'cat': '100', 'color': 'black'}

# %%
spam = {spam['color'] = 'black' if 'color' not in spam}
# Out:
#   File "<ipython-input-41-a2b5a2d351b0>", line 1
#     spam = {spam['color'] = 'black' if 'color' not in spam}
#                           ^
# SyntaxError: invalid syntax

# %%
if 'color' not in spam:
    spam['color'] = 'black'

# %% [markdown]
# 8. How do you "pretty print" dictionary values using which module and function?
